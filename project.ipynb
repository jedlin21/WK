# %%
import numpy as np
import glob
from PIL import Image
import matplotlib.pyplot as plt

# %%
files = glob.glob("./cathedral/*.jpg")

# %%
images = []
for file in files:
    images.append(np.array(Image.open(file)))

# %%
### odjęcie i próg

# %%
x = (images[0] - images[1])
x[x>=200] = 255
x[x<200] = 0

# %%
Image.fromarray(x)
# Out:
# <PIL.Image.Image image mode=RGB size=752x500 at 0x7F51C9E805C0>

# %%
### średnia

# %%
images = np.array(images)

# %%
Image.fromarray(np.mean(images, axis=0).astype('uint8'))
# Out:
# <PIL.Image.Image image mode=RGB size=752x500 at 0x7F51C975EBA8>

# %%
### mediana

# %%
Image.fromarray(np.median(images, axis=0).astype('uint8'))
# Out:
# <PIL.Image.Image image mode=RGB size=752x500 at 0x7F51C759E2E8>

# %%
np.
